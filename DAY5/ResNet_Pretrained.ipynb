# %%
from keras.preprocessing.image import ImageDataGenerator , load_img , img_to_array
from keras.applications.resnet50 import ResNet50 , preprocess_input , decode_predictions
import numpy as np
from keras.utils import plot_model

# %%
image = load_img('adolf.webp' , target_size=(224,224))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image = img_to_array(image)

# %%
image
# Out:
# array([[[103., 103., 103.],
#         [ 97.,  97.,  97.],
#         [ 92.,  92.,  92.],
#         ...,
#         [ 91.,  91.,  91.],
#         [ 93.,  93.,  93.],
#         [ 95.,  95.,  95.]],
#
#        [[102., 102., 102.],
#         [ 96.,  96.,  96.],
#         [ 91.,  91.,  91.],
#         ...,
#         [ 91.,  91.,  91.],
#         [ 93.,  93.,  93.],
#         [ 95.,  95.,  95.]],
#
#        [[100., 100., 100.],
#         [ 94.,  94.,  94.],
#         [ 88.,  88.,  88.],
#         ...,
#         [ 92.,  92.,  92.],
#         [ 93.,  93.,  93.],
#         [ 95.,  95.,  95.]],
#
#        ...,
#
#        [[199., 199., 199.],
#         [191., 191., 191.],
#         [170., 170., 170.],
#         ...,
#         [158., 158., 158.],
#         [162., 162., 162.],
#         [165., 165., 165.]],
#
#        [[188., 188., 188.],
#         [193., 193., 193.],
#         [184., 184., 184.],
#         ...,
#         [163., 163., 163.],
#         [167., 167., 167.],
#         [170., 170., 170.]],
#
#        [[142., 142., 142.],
#         [178., 178., 178.],
#         [187., 187., 187.],
#         ...,
#         [156., 156., 156.],
#         [160., 160., 160.],
#         [164., 164., 164.]]], dtype=float32)

# %%
image = image.reshape((1,image.shape[0],image.shape[1],image.shape[2]))

# %%
image.shape
# Out:
# (1, 224, 224, 3)

# %%
#prepare the image for the ResNet50 model
image = preprocess_input(image)

# %%
#load the model
model = ResNet50()

# %%
#predict the probability across all output classes
yhat = model.predict(image)
# Out:
# 1/1 [==============================] - 1s 903ms/step

# %%
#Convert the probabilities to class labels
label = decode_predictions(yhat)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step

# %%
label
# Out:
# [[('n03763968', 'military_uniform', 0.34401265),
#   ('n02883205', 'bow_tie', 0.07146162),
#   ('n03630383', 'lab_coat', 0.04659445),
#   ('n02787622', 'banjo', 0.036485486),
#   ('n02786058', 'Band_Aid', 0.031072164)]]

# %%
image = load_img('strawberry.jpg' , target_size=(224,224))

# %%
image = img_to_array(image)
image = image.reshape((1,image.shape[0],image.shape[1],image.shape[2]))
image = preprocess_input(image)
yhat = model.predict(image)
decode_predictions(yhat)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# [[('n07745940', 'strawberry', 0.9999852),
#   ('n12620546', 'hip', 6.2802474e-06),
#   ('n07753275', 'pineapple', 5.341695e-06),
#   ('n07760859', 'custard_apple', 9.773673e-07),
#   ('n02169497', 'leaf_beetle', 4.5773044e-07)]]
